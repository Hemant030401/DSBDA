# %%
import requests
import bs4
import pandas as pd

# %%
request=requests.get('https://www.flipkart.com/lifelong-chaze-milind-soman-czbc2701-27-5-t-road-cycle/p/itm17cb4f71a4fe0?pid=CCEG69KKJYE8ZHFG&lid=LSTCCEG69KKJYE8ZHFGM4RATJ&marketplace=FLIPKART&store=abc%2Fulv%2Fixt&srno=b_1_1&otracker=hp_omu_Beauty%252C%2BFood%252C%2BToys%2B%2526%2Bmore_2_7.dealCard.OMU_D44KL0ET2AE5_5&otracker1=hp_omu_PINNED_neo%2Fmerchandising_Beauty%252C%2BFood%252C%2BToys%2B%2526%2Bmore_NA_dealCard_cc_2_NA_view-all_5&fm=neo%2Fmerchandising&iid=en_Sg%2B9ADdUMCq8UEL6InspuuPP4L%2Fv66RWMniccpWg%2FZwOfLxjJcZG9Q6ZbqjkW%2BfCf0B8cjZgIsuGU0BUmanHyg%3D%3D&ppt=browse&ppn=browse&ssid=033di06kyo0000001684121845532')

# %%
request.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.914d0a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
soup=bs4.BeautifulSoup(request.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
reviews=soup.findAll('div',{'class':'t-ZTKy'})
for review in reviews:
    print(review.get_text(),'\n\n')
# Out:
# Best in this price range,I don't know why this is not popular .Recommend to life long to make unique sales strategy to promote this outstanding biycle.Person having height above 5.5 is best suitable.READ MORE
#
#
# Lose pedal Not Buy cycle very badREAD MORE
#
#
# The cycle is O.K and best suited for the elders.READ MORE
#
#
# I purchased this product and installed it by my own. Every thing was fine but when it put air in tyres, rear tyres tube comes out of tyre. Even it's finishing is very bad. Don't buy this product fro chase. Thanks.READ MORE
#
#
# Tayer puncturedREAD MORE
#
#
# Good Cycle for carrying 100kg weight...  Reasonable.... Good for Short termREAD MORE
#
#
# Very good product and excellent customer support.READ MORE
#
#
# nice product but seat needs to be modified according to the gender and weightREAD MORE
#
#
# ...

# %%
ratings=soup.findAll('span',{'class':'_3c3Px5'})
for rating in ratings:
    print(rating.get_text(),'\n\n')
# Out:
# 17
#
#
# 6
#
#
# 141
#
#
# 56
#
#
# 17
#
#
# 5
#
#
# 4
#
#
# 0
#
#
# 5
#
#
# 3
#
#
# 1
#
#
# 0
#
#
# 1
#
#
# 0
#
#
# 1
#
#
# 0
#
#
# 1
#
#
# 1
#
#
# 1
#
#
# 1
#
#
# 6
#
#
# 3
#
#
# 2
#
#
# 4
#
#
# 1
#
#
# 2
#
#
# 0
#
#
# 0
#
#
# 0
#
#
# 0
#
#
# 0
#
#
# 0
#
#
# 8
#
#
# 2
#
#
# 1
#
#
# 0
#
#
# 0
#
#
# 0

# %%
names=soup.findAll('p',{'class':'_2sc7ZR _2V5EHH'})
for name in names:
    print(name.get_text(),'\n\n')
# Out:
# dishant sehgl
#
#
# Sukhveer Singh
#
#
# KOLA UMAMAHESWARARAO
#
#
# Flipkart Customer
#
#
# Tushar  Mohanta
#
#
# Abhinay Pai
#
#
# Neetish Patnaik
#
#
# Flipkart Customer
#
#
# yasir anwar
#
#
# Pradeepan.p.k Pradeepan.p.k

# %%
names=soup.findAll('p',{'class':'_2sc7ZR _2V5EHH'})
reviews=soup.findAll('div',{'class':'t-ZTKy'})
revi=[]
name=[]

# %%
for item in names:
    name.append(item.text)

name
# Out:
# ['dishant sehgl',
#  'Sukhveer Singh',
#  'KOLA UMAMAHESWARARAO',
#  'Flipkart Customer',
#  'Tushar  Mohanta ',
#  'Abhinay Pai',
#  'Neetish Patnaik',
#  'Flipkart Customer',
#  'yasir anwar',
#  'Pradeepan.p.k Pradeepan.p.k']

# %%
for item in reviews:
    revi.append(item.text)

revi
# Out:
# ["Best in this price range,I don't know why this is not popular .Recommend to life long to make unique sales strategy to promote this outstanding biycle.Person having height above 5.5 is best suitable.READ MORE",
#  'Lose pedal Not Buy cycle very badREAD MORE',
#  'The cycle is O.K and best suited for the elders.READ MORE',
#  "I purchased this product and installed it by my own. Every thing was fine but when it put air in tyres, rear tyres tube comes out of tyre. Even it's finishing is very bad. Don't buy this product fro chase. Thanks.READ MORE",
#  'Tayer puncturedREAD MORE',
#  'Good Cycle for carrying 100kg weight...  Reasonable.... Good for Short termREAD MORE',
#  'Very good product and excellent customer support.READ MORE',
#  'nice product but seat needs to be modified according to the gender and weightREAD MORE',
# ...

# %%
df = {'name' : name,
      'review' : revi}
final_df = pd.DataFrame(df)
final_df
# Out:
#                           name  \
# 0                dishant sehgl
# 1               Sukhveer Singh
# 2         KOLA UMAMAHESWARARAO
# 3            Flipkart Customer
# 4             Tushar  Mohanta
# 5                  Abhinay Pai
# 6              Neetish Patnaik
# 7            Flipkart Customer
# 8                  yasir anwar
# 9  Pradeepan.p.k Pradeepan.p.k
#
#                                               review
# 0  Best in this price range,I don't know why this...
# 1         Lose pedal Not Buy cycle very badREAD MORE
# 2  The cycle is O.K and best suited for the elder...
# 3  I purchased this product and installed it by m...
# 4                           Tayer puncturedREAD MORE
# 5  Good Cycle for carrying 100kg weight...  Reaso...
# 6  Very good product and excellent customer suppo...
# 7  nice product but seat needs to be modified acc...
# 8  Look of cycle is elegant seems costly. Light w...
# 9                                 Very goodREAD MORE
