# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:/Users/Hemant/Desktop/DSBDA/DATASETS/heart.csv")

# %%
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
sns.lineplot(x='sex',y='age',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot(x='sex',y='thall',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='thall'>

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.scatterplot(x='age',y='chol',data=df)
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
sns.histplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.boxplot(x='age',y='thall',data=df)
# Out:
# <Axes: xlabel='age', ylabel='thall'>

# %%
sns.violinplot(x='age',data=df)
# Out:
# <Axes: xlabel='age'>

# %%
plt.scatter(x='age',y='chol',data=df)

# %%
#timeseries chart

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:/Users/Hemant/Desktop/DSBDA/DATASETS/heart.csv")

# %%
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
sns.lineplot(x='sex',y='thall',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='thall'>

# %%
sns.barplot(x='sex',y='thall',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='thall'>

# %%
sns.scatterplot(x='age',y='chol',data=df)
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
plt.scatter(x='age',y='chol',data=df)

# %%
sns.histplot(x='age',data=df)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.boxplot(x='age',y='thall',data=df)
# Out:
# <Axes: xlabel='age', ylabel='thall'>

# %%
sns.violinplot(x='age',data=df)
# Out:
# <Axes: xlabel='age'>

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,cmap='Greens')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,cmap='Greens')
# Out:
# <Axes: >

# %%
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
df['age']=pd.to_datetime(df['age'])
df['age'].plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,cmap='Greens')
# Out:
# C:\Users\Hemant\AppData\Local\Temp\ipykernel_8620\501764966.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap='Greens')
# <Axes: >

# %%
df
# Out:
#                               age  sex  cp  trtbps  chol  fbs  restecg  \
# 0   1970-01-01 00:00:00.000000063    1   3     145   233    1        0
# 1   1970-01-01 00:00:00.000000037    1   2     130   250    0        1
# 2   1970-01-01 00:00:00.000000041    0   1     130   204    0        0
# 3   1970-01-01 00:00:00.000000056    1   1     120   236    0        1
# 4   1970-01-01 00:00:00.000000057    0   0     120   354    0        1
# ..                            ...  ...  ..     ...   ...  ...      ...
# 298 1970-01-01 00:00:00.000000057    0   0     140   241    0        1
# 299 1970-01-01 00:00:00.000000045    1   3     110   264    0        1
# 300 1970-01-01 00:00:00.000000068    1   0     144   193    1        1
# 301 1970-01-01 00:00:00.000000057    1   0     130   131    0        1
# 302 1970-01-01 00:00:00.000000057    0   1     130   236    0        0
#
#      thalachh  exng  oldpeak  slp  caa  thall  output
# 0         150     0      2.3    0    0      1       1
# ...

# %%
df['oldpeak']=pd.to_datetime(df['oldpeak'])
df['oldpeak'].plot()
# Out:
# <Axes: >
